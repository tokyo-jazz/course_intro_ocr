# %%
from pathlib import Path
from course_intro_ocr_t1.data import MidvPackage
from tqdm import tqdm
from matplotlib import pyplot as plt
import numpy as np

# %%
DATASET_PATH = Path().absolute().parent.parent / 'midv500' / 'midv500_compressed'
assert DATASET_PATH.exists(), DATASET_PATH.absolute()

# %%
# Собираем список пакетов (MidvPackage) 
data_packs = MidvPackage.read_midv500_dataset(DATASET_PATH)
len(data_packs), type(data_packs[0])
# Out:
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\05_aze_passport\ground_truth\05_aze_passport.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\06_bra_passport\ground_truth\06_bra_passport.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\08_chn_homereturn\ground_truth\08_chn_homereturn.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\09_chn_id\ground_truth\09_chn_id.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\10_cze_id\ground_truth\10_cze_id.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\11_cze_passport\ground_truth\11_cze_passport.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\25_grc_passport\ground_truth\25_grc_passport.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\28_hun_passport\ground_truth\28_hun_passport.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\31_jpn_drvlic\ground_truth\31_jpn_drvlic.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\34_mda_passport\ground_truth\34_mda_passport.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\37_prt_id\ground_truth\37_prt_id.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\39_rus_internalpassport\ground_truth\39_rus_internalpassport.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\40_srb_id\ground_truth\40_srb_id.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\44_ukr_id\ground_truth\44_ukr_id.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# F:\bzimka\edu\course_intro_ocr\task1\course_intro_ocr_t1\data.py:42: UnicodeWarning: Can't read F:\bzimka\edu\midv500\midv500_compressed\45_ukr_passport\ground_truth\45_ukr_passport.json, non unicode text
#   warnings.warn(f"Can't read {self.gt_path}, non unicode text", UnicodeWarning)
# (50, course_intro_ocr_t1.data.MidvPackage)

# %%
# В каждом пакете - 300 штук DataItem
dp = data_packs[0]
di = dp[220]
type(dp), len(dp), type(di)
# Out:
# (course_intro_ocr_t1.data.MidvPackage, 300, course_intro_ocr_t1.data.DataItem)

# %%
# DataItem содержит пути до файлов изображения и разметки
di.gt_path, di.img_path
# Out:
# (WindowsPath('F:/bzimka/edu/midv500/midv500_compressed/01_alb_id/ground_truth/PS/PS01_11.json'),
#  WindowsPath('F:/bzimka/edu/midv500/midv500_compressed/01_alb_id/images/PS/PS01_11.tif'))

# %%
# в gt_data (данные json) quad в абсолютных значениях (пиксели)
np.array(di.gt_data['quad'])
# Out:
# array([[220, 299],
#        [598, 315],
#        [626, 571],
#        [202, 541]])

# %%
# Можно посмотреть изображения и разметку; в .quadrangle используются относительные единицы
print(di.quadrangle)
di.image
# Out:
# [[0.48888889 0.37375   ]
#  [1.32888889 0.39375   ]
#  [1.39111111 0.71375   ]
#  [0.44888889 0.67625   ]]
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=450x800>

# %%
# Можно отрисовать разметку
# Не обязательно весь документ виден в кадре
di.show()

# %%
# DataItem содержит в себе информацию, относится ли он к test_split и целиком ли разметка внутри кадра
di.is_test_split(), di.is_quad_inside()
# Out:
# (False, False)

# %%
print(data_packs[38][238].is_test_split())
data_packs[38][238].show()
# Out:
# True

# %%
## Статистика, как часто разметка не целиком в кадре
is_quad_inside = []
for dp in tqdm(data_packs):
    for i in range(len(dp)):
        is_quad_inside.append(dp[i].is_quad_inside())
is_quad_inside = np.array(is_quad_inside).astype(int)
print(f"В {is_quad_inside.sum()} из {len(is_quad_inside)} случаев разметка кропа(т.е. документ) целиком в кадре")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:18<00:00,  2.74it/s]
# В 9992 из 15000 случаев разметка кропа(т.е. документ) целиком в кадре

# %%
## Статистика test-split
is_test_split = []
for dp in tqdm(data_packs):
    for i in range(len(dp)):
        is_test_split.append(dp[i].is_test_split())
is_test_split = np.array(is_test_split).astype(int)
print(f"В {is_test_split.sum()} из {len(is_test_split)} случаев кадр принадлежит к test-split")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 49.30it/s]
# В 4250 из 15000 случаев кадр принадлежит к test-split

# %% [markdown]
# ## Classic CV baseline

# %% [markdown]
# ### Для работы baseline нужен установленныей OpenCV

# %%
import cv2

# %%
class SimpleBaselineCrop:
    """
    Baseline на основе поиска и сопоставления ключевых точек на шаблоне(ref) и запросе(query)
    Алгоритм:
        0. Найти ключевые точки(КТ) на ref
        1. Найти ключевые точки(КТ) на query
        2. Сопоставить КТ query и ref друг-другу
        3. На основе сопоставления найти гомографию из ref в query
        4. Отобразить 4 угла изображения ref в query - это искомый четырехугольник кропа
    """
    def __init__(self, ref_image):
        self.ref_image = ref_image
        
        # 0. Найти ключевые точки(КТ) на ref
        self.ref_kpts, self.ref_fts = self.compute_kps(
            self.ref_image
        )

    def compute_kps(self, img, response_quantile=0.25):
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        sift = cv2.SIFT_create()
        kp = sift.detect(gray, None)
        # фильтруем 25% неуверенных точек
        q_val = np.quantile(list(k.response for k in kp), response_quantile)
        kp = [k for k in kp if k.response > q_val]
        
        kp, features = sift.compute(gray, kp)
        return kp, features 
    
    def find_qr_homography(self, kp_q, ft_q, kp_r, ft_r, ratio=0.75):
        # 2. Сопоставить КТ query и ref друг-другу
        bf = cv2.BFMatcher()
        matches = bf.knnMatch(ft_q, ft_r, k=2)
        good = []

        # Дополнителный опциональный шаг - фильтрация Lowe, Lowe ratio-test:
        # Пусть есть лучший матч1 (query-kp, ref-kp)
        # Если есть другой возможный матч2 (query-kp, ref-kp2), и их качество
        # (т.е. расстояние в пространстве features) маленькое,
        # то нельзя быть уверенном, что матч1 - надежный, и проще его выбросить
        for m,n in matches:
            if m.distance <  ratio * n.distance:
                good.append([m])
                
        ptsA = np.zeros((len(good), 2), dtype="float")
        ptsB = np.zeros((len(good), 2), dtype="float")

        for (i, mlist) in enumerate(good):
            m = mlist[0]
            ptsA[i] = kp_q[m.queryIdx].pt
            ptsB[i] = kp_r[m.trainIdx].pt
        # 3. На основе сопоставления найти гомографию из ref в query
        (H, mask) = cv2.findHomography(ptsB, ptsA, method=cv2.RANSAC)
        return H
              
    def compute_crop(self, ref_img, hmg):
        # 4. Отобразить 4 угла изображения ref в query - это искомый четырехугольник кропа
        h, w, _ = ref_img.shape
        h = float(h)
        w = float(w)
        points = [
            [0, 0],
            [w, 0],
            [w, h],
            [0, h],
        ]
        points_crop = []
        for p in points:
            # применяем гомографию к точке, представленной в гомогенных координатах
            vec = hmg @ np.array([p[0], p[1], 1])
            points_crop.append([vec[0]/vec[-1], vec[1]/vec[-1]])
        return np.array(points_crop)
        
    def __call__(self, query_image):
        # 1. Найти ключевые точки(КТ) на query
        kpts, fts = self.compute_kps(query_image)
        
        homography = self.find_qr_homography(
            kpts, fts, self.ref_kpts, self.ref_fts
        )
        abs_crop = self.compute_crop(self.ref_image, homography)
        h, w, _ = query_image.shape
        rel_crop = abs_crop / np.array([[w, h]])
        return rel_crop

# %%
bcm = SimpleBaselineCrop(np.array(dp.template_item.image))

# %%
pred_quad = bcm(np.array(dp[0].image))

# %%
pred_quad, dp[0].quadrangle
# Out:
# (array([[0.05690939, 0.47378273],
#         [0.73707284, 0.33397009],
#         [0.92773878, 0.56708375],
#         [0.22825794, 0.72939492]]),
#  array([[0.05555556, 0.47375   ],
#         [0.73555556, 0.335     ],
#         [0.92666667, 0.5675    ],
#         [0.22666667, 0.72875   ]]))

# %%
dp[0].show(pred_quad)

# %%
results_dict = dict()

for dp in tqdm(data_packs):
    bcm = SimpleBaselineCrop(np.array(dp.template_item.image))
    for i in range(len(dp)):
        if dp[i].is_test_split():
            try:
                results_dict[dp[i].unique_key] = bcm(np.array(dp[i].image))
            except Exception as exc:
                # Для пропущенных в словаре ключей в метриках автоаматически засчитается IoU=0
                print(exc)
# Out:
#  22%|█████████████████████████▉                                                                                            | 11/50 [01:29<05:20,  8.23s/it]
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#  42%|█████████████████████████████████████████████████▌                                                                    | 21/50 [02:50<03:52,  8.00s/it]
# matmul: Input operand 0 does not have enough dimensions (has 0, gufunc core with signature (n?,k),(k,m?)->(n?,m?) requires 1)
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████                   | 42/50 [05:40<01:03,  8.00s/it]
# matmul: Input operand 0 does not have enough dimensions (has 0, gufunc core with signature (n?,k),(k,m?)->(n?,m?) requires 1)
#  86%|█████████████████████████████████████████████████████████████████████████████████████████████████████▍                | 43/50 [05:48<00:56,  8.09s/it]
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#  88%|███████████████████████████████████████████████████████████████████████████████████████████████████████▊              | 44/50 [06:33<01:54, 19.15s/it]
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# matmul: Input operand 0 does not have enough dimensions (has 0, gufunc core with signature (n?,k),(k,m?)->(n?,m?) requires 1)
# matmul: Input operand 0 does not have enough dimensions (has 0, gufunc core with signature (n?,k),(k,m?)->(n?,m?) requires 1)
#  90%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▏           | 45/50 [07:20<02:18, 27.70s/it]
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#  92%|████████████████████████████████████████████████████████████████████████████████████████████████████████████▌         | 46/50 [08:06<02:12, 33.20s/it]
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#  94%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████▉       | 47/50 [08:53<01:51, 37.15s/it]
# matmul: Input operand 0 does not have enough dimensions (has 0, gufunc core with signature (n?,k),(k,m?)->(n?,m?) requires 1)
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# matmul: Input operand 0 does not have enough dimensions (has 0, gufunc core with signature (n?,k),(k,m?)->(n?,m?) requires 1)
#  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎    | 48/50 [09:39<01:19, 39.78s/it]
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋  | 49/50 [10:26<00:42, 42.12s/it]
# OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\calib3d\src\fundam.cpp:385: error: (-28:Unknown error code -28) The input arrays should have at least 4 corresponding point sets to calculate Homography in function 'cv::findHomography'
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [11:09<00:00, 13.39s/it]

# %% [markdown]
# ### Сохраним результаты и измерим точность
# Результаты - словарь с ключем DataItem.unique_key() и значением предсказанным quadrangle в относительных единицах.

# %%
from course_intro_ocr_t1.metrics import dump_results_dict, measure_crop_accuracy

# %%
dump_results_dict(results_dict, Path() / 'pred.json')

# %%
acc = measure_crop_accuracy(
    Path() / 'pred.json',
    Path() / 'gt.json'
)

# %%
print("Точность кропа: {:1.4f}".format(acc))
# Out:
# Точность кропа: 0.9619
